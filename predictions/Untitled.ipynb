# %%
from lr_rfr_streampredictions import *
import torch
from torch.optim import SGD
import torch.nn as nn
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/z_/7ykdsvqj4mj_sp60rydmf9_w0000gn/T/ipykernel_10535/989090228.py in <module>
# ----> 1 from lr_rfr_streampredictions import *
#       2 import torch
#       3 from torch.optim import SGD
#       4 import torch.nn as nn
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'lr_rfr_streampredictions'

# %%
data = pd.read_csv('../csv_files/four_week_data.csv')

# %%
data
# Out:
#                           artist            title  unified_song_id  \
# 0                     Gucci Mane  Gingerbread Man            91914
# 1                     Gucci Mane  Gingerbread Man            91914
# 2                     Gucci Mane  Gingerbread Man            91914
# 3                     Gucci Mane  Gingerbread Man            91914
# 4                     Gucci Mane  Gingerbread Man            91914
# ...                          ...              ...              ...
# 14567477  Tiesto & Lucas & Steve          ZENLESS        245214101
# 14567478  Tiesto & Lucas & Steve          ZENLESS        245214101
# 14567479  Tiesto & Lucas & Steve          ZENLESS        245214101
# 14567480  Tiesto & Lucas & Steve          ZENLESS        245214101
# 14567481  Tiesto & Lucas & Steve          ZENLESS        245214101
#
#                 date release_date  this_day  this_week  days_since_release  \
# 0         2021-12-22   2009-12-04       952     6066.0                4401
# ...
